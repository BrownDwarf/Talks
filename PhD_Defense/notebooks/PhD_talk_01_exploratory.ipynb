# %% [markdown]
# # PhD talk prepation
# ### I. Some exploratory graphics and stuff.

# %%
import os
print os.environ['BAADE']
BAADE = os.environ['BAADE']+'/'
# Out:
# /Volumes/cambridge/Astronomy/BD/BAADE

# %%
from IPython.display import Image

# %%
Image(filename=BAADE+'document/figures/OPH_349_I_image.png')
